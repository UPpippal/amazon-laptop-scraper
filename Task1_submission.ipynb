# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff3972fb-e8ec-4bc2-b272-b1903e1f1ea7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff3972fb-e8ec-4bc2-b272-b1903e1f1ea7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

with open("Amazon_laptop.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f.read(), "html.parser")

products = soup.find_all(
    "div",
    {"data-component-type": "s-search-result"}
)

print("Products Found:", len(products))
# Out:
# Products Found: 22

# %%
data = []

for product in products:

    title_tag = product.find("h2")
    title = title_tag.get_text(strip=True) if title_tag else "N/A"

    image_tag = product.find("img", class_="s-image")
    image = image_tag.get("src", "N/A") if image_tag else "N/A"

    rating_tag = product.find("span", class_="a-icon-alt")
    rating = rating_tag.get_text(strip=True) if rating_tag else "N/A"

    price_tag = product.find("span", class_="a-offscreen")
    price = price_tag.get_text(strip=True) if price_tag else "N/A"

    result_type = "Ad" if "Sponsored" in product.get_text() else "Organic"

    data.append({
        "Title": title,
        "Image": image,
        "Rating": rating,
        "Price": price,
        "Result Type": result_type
    })

df = pd.DataFrame(data)

df.head()
# Out:
#                                                Title  \
# 0  Acer Smartchoice Aspire One, AMD Ryzen 3-7320U...
# 1  HP 15 Smartchoice, Intel Core Ultra 5 125H (24...
# 2  Acer Smartchoice Aspire One, Intel Core Celero...
# 3  HP Smartchoice Omnibook 5 OLED (Previously Pav...
# 4  HP Victus, AMD Ryzen 7 7445HS, 6GB RTX 4050, 1...
#
#                                               Image              Rating  \
# 0  ./Amazon_laptop_files/71ouu-iX3pL._AC_UY218_.jpg  5.0 out of 5 stars
# 1  ./Amazon_laptop_files/71vhdLDaDQL._AC_UY218_.jpg  3.7 out of 5 stars
# 2  ./Amazon_laptop_files/71uoRYyilhL._AC_UY218_.jpg  3.3 out of 5 stars
# 3  ./Amazon_laptop_files/71IdAMTOjZL._AC_UY218_.jpg  4.2 out of 5 stars
# 4  ./Amazon_laptop_files/71r2ySSfgBL._AC_UY218_.jpg  4.2 out of 5 stars
#
#      Price Result Type
# 0  ₹39,990          Ad
# 1  ₹84,990          Ad
# 2  ₹35,990     Organic
# 3  ₹67,889     Organic
# 4  ₹89,990     Organic

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

filename = f"amazon_laptops_{timestamp}.csv"

df.to_csv(filename, index=False)

print("Saved:", filename)
print("Total Products:", len(df))
# Out:
# Saved: amazon_laptops_20260604_141813.csv
# Total Products: 22

# %%
from google.colab import files

files.download(filename)
